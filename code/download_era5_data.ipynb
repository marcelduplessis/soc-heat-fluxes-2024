# %% [markdown]
# #### Download ERA5 data for the State of the Climate Report

# %%
from functions.download_era5_cdsapi import download_era5_cdsapi

import numpy as np
import calendar
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
dwn_path = '/Volumes/LaCie/Work/data/era5/2024_soc_report/'

years = np.arange(1991, 1998, 1)
months = np.arange(1, 13, 1)

var = [
    'surface_sensible_heat_flux',    
    # '2m_dewpoint_temperature',
    # '2m_temperature',
    # '10m_v_component_of_wind',
    # '10m_u_component_of_wind',
    # 'sea_surface_temperature',
    # 'skin_temperature',
    # 'surface_pressure',
    'surface_net_solar_radiation',
    'surface_net_thermal_radiation',
    'surface_latent_heat_flux',
    'sea_ice_cover',
    # 'total_precipitation',
    # 'evaporation'
      ]

# %%
# download hourly files for 2023

for v in var:
    
    for year in years:
        
        for month in months:
            
            # Determine the number of days in the current month
            num_days = calendar.monthrange(year, month)[1]
            
            # Create a list of days using list comprehension
            days = [f'{d:02}' for d in range(1, num_days + 1)]
            
            # Format month as a string with leading zero if needed
            month_str = f'{month:02}'
            
            # Download Monthly Data
            # dwn_era5.download_era5_cdsapi(var=v, days=days, month=month_str, year=str(year), dataset='reanalysis-era5-single-levels-monthly-means', product_type='monthly_averaged_reanalysis', path=dwn_path)
            download_era5_cdsapi(var=v, days=days, month=month_str, year=str(year), dataset='reanalysis-era5-single-levels', product_type='reanalysis', path=dwn_path)

# %%
# download monthly files

for v in var:
    
    for year in years:
        
        for month in months:
            
            # Determine the number of days in the current month
            num_days = calendar.monthrange(year, month)[1]
            
            # Create a list of days using list comprehension
            days = [f'{d:02}' for d in range(1, num_days + 1)]
            
            # Format month as a string with leading zero if needed
            month_str = f'{month:02}'
            
            # Download Monthly Data
            # dwn_era5.download_era5_cdsapi(var=v, days=days, month=month_str, year=str(year), dataset='reanalysis-era5-single-levels-monthly-means', product_type='monthly_averaged_reanalysis', path=dwn_path)
            download_era5_cdsapi(var=v, days=days, month=month_str, year=str(year), dataset='reanalysis-era5-single-levels-monthly-means', product_type='reanalysis', path=dwn_path)
# Out:
# 2024-02-02 17:26:46,331 INFO Welcome to the CDS
# 2024-02-02 17:26:46,331 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-02-02 17:26:46,685 INFO Request is queued
# 2024-02-02 19:03:46,170 INFO Request is completed
# 2024-02-02 19:03:46,175 INFO Downloading https://download-0011-clone.copernicus-climate.eu/cache-compute-0011/cache/data3/adaptor.mars.internal-1706893411.7325404-31860-14-55786628-0144-4403-84c7-9b76802008a5.nc to /Volumes/LaCie/Work/data/era5/2024_soc_report/surface_sensible_heat_flux_199101.nc (23.8M)
# 2024-02-02 19:04:27,772 INFO Download rate 586K/s
# 2024-02-02 19:04:28,251 INFO Welcome to the CDS
# 2024-02-02 19:04:28,254 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-02-02 19:04:28,563 INFO Request is queued
# 2024-02-02 20:49:17,483 WARNING Connection error: [('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'
Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))]. Attempt 2 of 500.
# 2024-02-03 19:17:04,363 WARNING Retrying in 120 seconds
# 2024-02-03 20:17:35,974 INFO Retrying now...
# 2024-02-03 21:34:05,530 ERROR Download interupted: HTTPSConnectionPool(host='download-0001-clone.copernicus-climate.eu', port=443): Read timed out.
# IOStream.flush timed out
# 2024-02-03 21:34:07,081 ERROR Download incomplete, downloaded 7404544 byte(s) out of 24960768
# 2024-02-03 21:34:07,082 WARNING Sleeping 10 seconds
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-02-03 21:41:11,507 WARNING Resuming download at byte 7404544
# 2024-02-03 21:41:11,522 WARNING Connection error: [HTTPSConnectionPool(host='download-0001-clone.copernicus-climate.eu', port=443): Max retries exceeded with url: /cache-compute-0001/cache/data8/adaptor.mars.internal-1706956512.0807774-21898-17-e0296e8d-16fe-41cb-8857-78988e0f46cc.nc (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x115a03170>: Failed to resolve 'download-0001-clone.copernicus-climate.eu' ([Errno 8] nodename nor servname provided, or not known)"))]. Attempt 1 of 500.
# 2024-02-03 21:41:11,523 WARNING Retrying in 120 seconds
# 2024-02-03 21:47:32,432 INFO Retrying now...
# 2024-02-03 22:05:58,792 ERROR Download interupted: HTTPSConnectionPool(host='download-0001-clone.copernicus-climate.eu', port=443): Read timed out.
# 2024-02-03 22:05:58,793 ERROR Download incomplete, downloaded 7464960 byte(s) out of 24960768
# 2024-02-03 22:05:58,793 WARNING Sleeping 15.0 seconds
# 2024-02-03 22:19:33,246 WARNING Resuming download at byte 7464960
# HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Read timed out. (read timeout=60)
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/urllib3/response.py:712, in HTTPResponse._error_catcher(self)
#     711 try:
# --> 712     yield
#     714 except SocketTimeout as e:
#     715     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     716     # there is yet no clean way to get at it from this context.
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/urllib3/response.py:833, in HTTPResponse._raw_read(self, amt)
#     823         if (
#     824             self.enforce_content_length
#     825             and self.length_remaining is not None
#    (...)
#     831             # raised during streaming, so all calls with incorrect
#     832             # Content-Length are caught.
# --> 833             raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     835 if data:
#
# IncompleteRead: IncompleteRead(6300170 bytes read, 11195638 more expected)
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/urllib3/response.py:934, in HTTPResponse.stream(self, amt, decode_content)
#     933 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 934     data = self.read(amt=amt, decode_content=decode_content)
#     936     if data:
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/urllib3/response.py:905, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     901 while len(self._decoded_buffer) < amt and data:
#     902     # TODO make sure to initially read enough data to get past the headers
#     903     # For example, the GZ file header takes 10 bytes, we don't want to read
#     904     # it one byte at a time
# --> 905     data = self._raw_read(amt)
#     906     decoded_data = self._decode(data, decode_content, flush_decoder)
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/urllib3/response.py:811, in HTTPResponse._raw_read(self, amt)
#     809 fp_closed = getattr(self._fp, "closed", False)
# --> 811 with self._error_catcher():
#     812     data = self._fp_read(amt) if not fp_closed else b""
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/urllib3/response.py:729, in HTTPResponse._error_catcher(self)
#     727 except (HTTPException, OSError) as e:
#     728     # This includes IncompleteRead.
# --> 729     raise ProtocolError(f"Connection broken: {e!r}", e) from e
#     731 # If no exception is thrown, we should avoid cleaning up
#     732 # unnecessarily.
#
# ProtocolError: ('Connection broken: IncompleteRead(6300170 bytes read, 11195638 more expected)', IncompleteRead(6300170 bytes read, 11195638 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[4], line 20
#      16 month_str = f'{month:02}'
#      18 # Download Monthly Data
#      19 # dwn_era5.download_era5_cdsapi(var=v, days=days, month=month_str, year=str(year), dataset='reanalysis-era5-single-levels-monthly-means', product_type='monthly_averaged_reanalysis', path=dwn_path)
# ---> 20 download_era5_cdsapi(var=v, days=days, month=month_str, year=str(year), dataset='reanalysis-era5-single-levels-monthly-means', product_type='reanalysis', path=dwn_path)
#
# File ~/Library/CloudStorage/GoogleDrive-marceldpl10@gmail.com/My Drive/projects/2024_soc_heat_flux/soc-heat-fluxes-2024/code/functions/download_era5_cdsapi.py:47, in download_era5_cdsapi(var, days, month, year, dataset, product_type, path)
#      27     params = {
#      28               'variable': [var],
#      29               'product_type': product_type,
#    (...)
#      42               'format': 'netcdf'
#      43              }
#      45 fl = cds.retrieve(dataset, params) # download the file
# ---> 47 fl.download(path+str(var)+'_'+str(year)+str(month)+'.nc') # load into memory
#      49 return
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/cdsapi/api.py:171, in Result.download(self, target)
#     170 def download(self, target=None):
# --> 171     return self._download(self.location, self.content_length, target)
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/cdsapi/api.py:131, in Result._download(self, url, size, target)
#     129 pbar.update(total)
#     130 with open(target, mode) as f:
# --> 131     for chunk in r.iter_content(chunk_size=1024):
#     132         if chunk:
#     133             f.write(chunk)
#
# File ~/opt/anaconda3/envs/soc_env/lib/python3.12/site-packages/requests/models.py:818, in Response.iter_content.<locals>.generate()
#     816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
# --> 818     raise ChunkedEncodingError(e)
#     819 except DecodeError as e:
#     820     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(6300170 bytes read, 11195638 more expected)', IncompleteRead(6300170 bytes read, 11195638 more expected))
